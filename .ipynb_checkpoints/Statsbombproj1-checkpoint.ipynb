# %%
from statsbombpy import sb
import pandas as pd

# %%
comps = sb.competitions()
# Out:
# credentials were not supplied. open data access only

# %%
comps
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# ...

# %%
euro = sb.matches(competition_id = 55, season_id=43)
euro
# Out:
# credentials were not supplied. open data access only
#     match_id  match_date      kick_off         competition season  \
# 0    3788753  2021-06-16  15:00:00.000  Europe - UEFA Euro   2020
# 1    3788765  2021-06-20  18:00:00.000  Europe - UEFA Euro   2020
# 2    3795107  2021-07-02  21:00:00.000  Europe - UEFA Euro   2020
# 3    3795221  2021-07-07  21:00:00.000  Europe - UEFA Euro   2020
# 4    3795506  2021-07-11  21:00:00.000  Europe - UEFA Euro   2020
# 5    3794688  2021-06-29  18:00:00.000  Europe - UEFA Euro   2020
# 6    3794692  2021-06-29  21:00:00.000  Europe - UEFA Euro   2020
# 7    3794686  2021-06-28  18:00:00.000  Europe - UEFA Euro   2020
# 8    3794687  2021-06-27  21:00:00.000  Europe - UEFA Euro   2020
# 9    3794685  2021-06-26  21:00:00.000  Europe - UEFA Euro   2020
# 10   3788774  2021-06-23  21:00:00.000  Europe - UEFA Euro   2020
# 11   3788771  2021-06-22  21:00:00.000  Europe - UEFA Euro   2020
# ...

# %%
euro['home_team']
# Out:
# 0             Finland
# 1         Switzerland
# 2             Belgium
# 3             England
# 4               Italy
# 5             England
# 6              Sweden
# 7             Croatia
# 8             Belgium
# 9               Italy
# 10            Germany
# 11            Croatia
# 12     Czech Republic
# 13            Finland
# 14            Ukraine
# 15            Hungary
# 16            England
# 17            Ukraine
# 18            Denmark
# 19            England
# 20        Netherlands
# 21             France
# 22        Netherlands
# 23              Wales
# 24             Russia
# 25             Sweden
# 26           Portugal
# 27              Italy
# 28              Italy
# 29             Turkey
# 30           Portugal
# 31              Spain
# 32            Croatia
# 33            Austria
# 34             Turkey
# 35              Italy
# 36    North Macedonia
# 37        Switzerland
# 38            Ukraine
# 39     Czech Republic
# 40        Netherlands
# ...

# %%
df = pd.DataFrame.from_dict(euro)

# %%
filt = (df['home_team'] == 'England') | (df['away_team'] == 'England')

# %%
Engdf = df[filt]
list(Engdf['match_id'])
# Out:
# [3795221, 3795506, 3794688, 3788772, 3788759, 3788745, 3795187]

# %%
# Out:
# credentials were not supplied. open data access only

# %%
events
# Out:
# [{'event_uuid': 'de1529bc-c1f4-43fa-abb9-a802789f823b',
#   'visible_area': [16.9263686636458,
#    80.0,
#    45.2409365758073,
#    0.0,
#    74.6462231305934,
#    0.0,
#    102.478366922304,
#    80.0,
#    16.9263686636458,
#    80.0],
#   'freeze_frame': [{'teammate': True,
#     'actor': False,
#     'keeper': False,
#     'location': [34.91119, 45.845078]},
#    {'teammate': True,
#     'actor': False,
#     'keeper': False,
#     'location': [35.063225, 37.033367]},
#    {'teammate': True,
#     'actor': False,
#     'keeper': False,
#     'location': [46.0065, 58.671535]},
#    {'teammate': True,
#     'actor': False,
#     'keeper': False,
#     'location': [48.133804, 35.3893]},
#    {'teammate': True,
#     'actor': False,
#     'keeper': False,
#     'location': [48.5656, 22.849]},
#    {'teammate': True,
#     'actor': False,
#     'keeper': False,
#     'location': [48.78207, 47.11318]},
#    {'teammate': True,
#     'actor': False,
#     'keeper': False,
# ...
