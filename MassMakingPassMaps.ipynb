# %%
#just tryna copy this https://mplsoccer.readthedocs.io/en/latest/gallery/pitch_plots/plot_arrows.html
import pandas as pd
from mplsoccer import Pitch, FontManager
from matplotlib import rcParams
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/fsa168/Desktop/PythonPractice/SoccerProj1/final_df2.csv', index_col=0)
df
# Out:
#      period                   player  x_start  y_start  \
# 0         1            Ciro Immobile     60.0     40.0
# 1         1           Marco Verratti     48.0     35.7
# 2         1      Giovanni Di Lorenzo     39.2     68.4
# 3         1         Leonardo Bonucci     25.3     46.4
# 4         1        Giorgio Chiellini     23.9     18.6
# ..      ...                      ...      ...      ...
# 880       4          Bryan Cristante     74.9     19.1
# 881       4  Jorge Luiz Frello Filho     78.7     39.1
# 882       4      Giovanni Di Lorenzo     96.4     69.2
# 883       4         Domenico Berardi     96.1     75.7
# 884       4      Alessandro Florenzi     19.5      8.3
#
#               recipient_name  x_end  y_end pass_type pass_outcome
# 0             Marco Verratti   49.5   33.2  Kick Off          NaN
# 1        Giovanni Di Lorenzo   39.0   70.7       NaN          NaN
# 2           Leonardo Bonucci   24.9   46.7       NaN          NaN
# ...

# %%
ITAsquad = list(df['player'].value_counts().keys())

# %%
for eachplayer in ITAsquad:
    pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
    fig, ax = pitch.draw(figsize=(7,4.8), constrained_layout=True, tight_layout=False)
    fig.set_facecolor('#22312b')
    ax.set_title(f'{eachplayer} Completed Passes', fontsize=20, color='white')

    filt = df['player'] == eachplayer
    player_df = df.loc[filt]
    player_df_slim = player_df[['x_start', 'y_start','x_end','y_end','pass_outcome']]
    player_df_mask_complete = player_df_slim.pass_outcome.isnull()
    player_completed_passes = player_df_slim[player_df_mask_complete]
    
    player_fig = pitch.arrows(player_completed_passes.x_start,player_completed_passes.y_start,player_completed_passes.x_end,player_completed_passes.y_end, width=2, headwidth=5,headlength=5,color='#ad993c', ax=ax, label='completed passes')

    # fig.savefig('/Users/fsa168/Desktop/PythonPractice/SoccerProj1/Figs/' + eachplayer)

# %%
pitch1 = Pitch()

print(dir(pitch1))
# Out:
# ['__abstractmethods__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_arc_angles_equal_aspect', '_diameter_circle_equal_aspect', '_draw_arc', '_draw_ax', '_draw_circles_and_arcs', '_draw_ellipse', '_draw_goals', '_draw_juego_de_posicion', '_draw_line', '_draw_pitch_markings', '_draw_rectangle', '_draw_shade_middle', '_draw_stripe', '_draw_stripe_grass', '_init_circles_and_arcs', '_init_circles_and_arcs_equal_aspect', '_plain_stripes', '_reflect_2d', '_reverse_annotate_if_vertical', '_reverse_if_vertical', '_reverse_vertices_if_vertical', '_scale_pad', '_set_axes', '_set_background', '_set_extent', '_setup_subplots', '_to_ax_coord', '_validate_pad', '_validation_ch
# ...
