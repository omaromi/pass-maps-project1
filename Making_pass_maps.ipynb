# %%
#just tryna copy this https://mplsoccer.readthedocs.io/en/latest/gallery/pitch_plots/plot_arrows.html
import pandas as pd
from mplsoccer import Pitch, FontManager
from matplotlib import rcParams
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/fsa168/Desktop/PythonPractice/SoccerProj1/final_df2.csv', index_col=0)
df
# Out:
#      period                   player  x_start  y_start  \
# 0         1            Ciro Immobile     60.0     40.0
# 1         1           Marco Verratti     48.0     35.7
# 2         1      Giovanni Di Lorenzo     39.2     68.4
# 3         1         Leonardo Bonucci     25.3     46.4
# 4         1        Giorgio Chiellini     23.9     18.6
# ..      ...                      ...      ...      ...
# 880       4          Bryan Cristante     74.9     19.1
# 881       4  Jorge Luiz Frello Filho     78.7     39.1
# 882       4      Giovanni Di Lorenzo     96.4     69.2
# 883       4         Domenico Berardi     96.1     75.7
# 884       4      Alessandro Florenzi     19.5      8.3
#
#               recipient_name  x_end  y_end pass_type pass_outcome
# 0             Marco Verratti   49.5   33.2  Kick Off          NaN
# 1        Giovanni Di Lorenzo   39.0   70.7       NaN          NaN
# 2           Leonardo Bonucci   24.9   46.7       NaN          NaN
# ...

# %%
df_slim = df[['x_start', 'y_start','x_end','y_end','pass_outcome']]
df_slim.head()
# Out:
#    x_start  y_start  x_end  y_end pass_outcome
# 0     60.0     40.0   49.5   33.2          NaN
# 1     48.0     35.7   39.0   70.7          NaN
# 2     39.2     68.4   24.9   46.7          NaN
# 3     25.3     46.4   24.4   17.7          NaN
# 4     23.9     18.6   16.4   44.1          NaN

# %%
mask_complete = df_slim.pass_outcome.isnull()

# %%
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')

pitch.arrows(df_slim[mask_complete].x_start, df_slim[mask_complete].y_start, df_slim[mask_complete].x_end,df_slim[mask_complete].y_end, width=2, headwidth=10,headlength=10, color='#ad993c', ax=ax, label='completed passes')

# %%
ITA_squad = list(df['player'].value_counts().keys())

# %%
filt = (df['player'] == 'Marco Verratti') & (df['period'] == 1)
mv1_df = df.loc[filt]
mv1_df
# Out:
#      period          player  x_start  y_start               recipient_name  \
# 1         1  Marco Verratti     48.0     35.7          Giovanni Di Lorenzo
# 15        1  Marco Verratti     44.7     18.6      Jorge Luiz Frello Filho
# 23        1  Marco Verratti     29.6     48.1          Giovanni Di Lorenzo
# 26        1  Marco Verratti     48.9     69.8             Leonardo Bonucci
# 28        1  Marco Verratti     48.3     52.2      Jorge Luiz Frello Filho
# 29        1  Marco Verratti     50.9     41.9  Emerson Palmieri dos Santos
# 33        1  Marco Verratti     79.1      9.4              Lorenzo Insigne
# 35        1  Marco Verratti     92.6     13.9               Nicolò Barella
# 45        1  Marco Verratti     13.0     28.1      Jorge Luiz Frello Filho
# 50        1  Marco Verratti     55.7     26.3              Lorenzo Insigne
# 53        1  Marco Verratti     74.9     13.7              Lorenzo Insigne
# ...

# %%
mv1_df_slim = mv1_df[['x_start', 'y_start','x_end','y_end','pass_outcome']]
mv1_df_mask_complete = mv1_df_slim.pass_outcome.isnull()

# %%
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(7,4.8), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')

mv_fig1 = pitch.arrows(mv1_df_slim[mv1_df_mask_complete].x_start, mv1_df_slim[mv1_df_mask_complete].y_start, mv1_df_slim[mv1_df_mask_complete].x_end,mv1_df_slim[mv1_df_mask_complete].y_end, width=2, headwidth=5,headlength=5, color='#ad993c', ax=ax, label='completed passes')

# %% [markdown]
# First time I did this for Marco Veratti for the entire game, I looked at the resulting map and realized that the positions on the x-y axis are absolute and not relative. So the fact that teams switch sides at halftime made the map nonsensical. I had to go back to my original data cleaning to include and retain the 'period' column.
#
# I understand that periods 1 and 3 are the same direction and periods 2 and 4 are the same direction, but I do not know right now how to unify them in the right orientation

# %%
#fig.savefig('/Users/fsa168/Desktop/PythonPractice/SoccerProj1/mv_fig1.png')

# %%
filt2 = (df['player'] == 'Marco Verratti') & (df['period'] == 2)
mv2_df = df.loc[filt2]
mv2_df_slim = mv2_df[['x_start', 'y_start','x_end','y_end','pass_outcome']]
mv2_df_mask_complete = mv2_df_slim.pass_outcome.isnull()
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(7,4.8), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')

mv_fig2 = pitch.arrows(mv2_df_slim[mv2_df_mask_complete].x_start, mv2_df_slim[mv2_df_mask_complete].y_start, mv2_df_slim[mv2_df_mask_complete].x_end,mv2_df_slim[mv2_df_mask_complete].y_end, width=2, headwidth=5,headlength=5, color='#ad993c', ax=ax, label='completed passes')

# %%
pitch1 = Pitch()
pitch1.__dir__()
# Out:
# ['pitch_type',
#  'half',
#  'pitch_color',
#  'line_color',
#  'linewidth',
#  'spot_scale',
#  'line_zorder',
#  'stripe',
#  'stripe_color',
#  'stripe_zorder',
#  'pad_left',
#  'pad_right',
#  'pad_bottom',
#  'pad_top',
#  'positional',
#  'positional_zorder',
#  'positional_linewidth',
#  'positional_linestyle',
#  'positional_color',
#  'shade_middle',
#  'shade_color',
#  'shade_zorder',
#  'pitch_length',
#  'pitch_width',
#  'goal_type',
#  'goal_alpha',
#  'line_alpha',
#  'axis',
#  'label',
#  'tick',
#  'diameter1',
#  'diameter2',
#  'diameter_spot1',
#  'diameter_spot2',
#  'arc1_theta1',
#  'arc1_theta2',
#  'arc2_theta1',
#  'arc2_theta2',
#  'extent',
#  'visible_pitch',
#  'ax_aspect',
#  'kde_clip',
#  'hexbin_gridsize',
#  'hex_extent',
#  'vertical',
#  'reverse_cmap',
#  'standardizer',
#  'dim',
#  'stripe_end',
#  'stripe_start',
#  'grass_stripe_end',
#  'grass_stripe_start',
#  'goal_left',
#  'goal_right',
#  '__module__',
#  '_scale_pad',
# ...
